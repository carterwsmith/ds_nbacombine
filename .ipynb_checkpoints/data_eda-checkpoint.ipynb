# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('combine_rookie_data_cleaned.csv')

# %%
df.head()
# Out:
#    SEASON  PLAYER_ID_combine TEAM_ABBREVIATION             PLAYER_NAME  \
# 0    2014             203919               MEM            Jordan Adams
# 1    2014             203937               SAS           Kyle Anderson
# 2    2014             203648               NYK  Thanasis Antetokounmpo
# 3    2014             203946               CHI        Cameron Bairstow
# 4    2014             203920               ORL              Khem Birch
#
#   POSITION  HEIGHT_WO_SHOES  HEIGHT_W_SHOES  WEIGHT  WINGSPAN  STANDING_REACH  \
# 0       SG            75.50           76.75   208.8     82.00           102.0
# 1       SF            79.50           80.50   230.1     86.75           107.5
# 2       SF            77.25           78.25   205.2     84.00           104.5
# 3       PF            80.75           81.75   252.4     84.75           107.0
# 4       PF            79.50           81.25   208.8     85.00           107.0
#
#    ...  FG_PCT  FTA  FTM  FT_PCT  OREB   PF  PTS  REB  STL  TOV
# ...

# %%
df.columns
# Out:
# Index(['SEASON', 'PLAYER_ID_combine', 'TEAM_ABBREVIATION', 'PLAYER_NAME',
#        'POSITION', 'HEIGHT_WO_SHOES', 'HEIGHT_W_SHOES', 'WEIGHT', 'WINGSPAN',
#        'STANDING_REACH', 'BODY_FAT_PCT', 'HAND_LENGTH', 'HAND_WIDTH',
#        'STANDING_VERTICAL_LEAP', 'MAX_VERTICAL_LEAP', 'LANE_AGILITY_TIME',
#        'MODIFIED_LANE_AGILITY_TIME', 'THREE_QUARTER_SPRINT', 'BENCH_PRESS',
#        'SPOT_FIFTEEN_CORNER_LEFT', 'SPOT_FIFTEEN_BREAK_LEFT',
#        'SPOT_FIFTEEN_TOP_KEY', 'SPOT_FIFTEEN_BREAK_RIGHT',
#        'SPOT_FIFTEEN_CORNER_RIGHT', 'SPOT_COLLEGE_CORNER_LEFT',
#        'SPOT_COLLEGE_BREAK_LEFT', 'SPOT_COLLEGE_TOP_KEY',
#        'SPOT_COLLEGE_BREAK_RIGHT', 'SPOT_COLLEGE_CORNER_RIGHT',
#        'SPOT_NBA_CORNER_LEFT', 'SPOT_NBA_BREAK_LEFT', 'SPOT_NBA_TOP_KEY',
#        'SPOT_NBA_BREAK_RIGHT', 'SPOT_NBA_CORNER_RIGHT',
#        'OFF_DRIB_FIFTEEN_BREAK_LEFT', 'OFF_DRIB_FIFTEEN_TOP_KEY',
#        'OFF_DRIB_FIFTEEN_BREAK_RIGHT', 'OFF_DRIB_COLLEGE_BREAK_LEFT',
# ...

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#             SEASON  PLAYER_ID_combine  HEIGHT_WO_SHOES  HEIGHT_W_SHOES  \
# count   249.000000       2.490000e+02       248.000000      248.000000
# mean   2016.136546       1.364904e+06        77.422379       78.688508
# std       1.413297       5.537703e+05         3.101321        3.073986
# min    2014.000000       2.036480e+05        68.250000       69.500000
# 25%    2015.000000       1.626164e+06        75.500000       76.500000
# 50%    2016.000000       1.627782e+06        77.250000       78.750000
# 75%    2017.000000       1.628503e+06        79.750000       81.000000
# max    2018.000000       1.629118e+06        85.250000       86.250000
#
#            WEIGHT    WINGSPAN  STANDING_REACH  BODY_FAT_PCT  HAND_LENGTH  \
# count  247.000000  248.000000       248.00000    245.000000   247.000000
# mean   212.417814   82.689516       103.09879      7.075306     8.734818
# std     22.328481    3.622198         4.68408      2.349527     0.430686
# ...

# %%
df.FG3_PCT.hist()

# %%
df.SPOT_NBA_TOP_KEY.hist()

# %%
df.boxplot(column=['HAND_LENGTH', 'HAND_WIDTH'])

# %%
df[['STANDING_REACH', 'STANDING_VERTICAL_LEAP', 'BLK']].corr()
# Out:
#                         STANDING_REACH  STANDING_VERTICAL_LEAP       BLK
# STANDING_REACH                1.000000               -0.307703  0.356624
# STANDING_VERTICAL_LEAP       -0.307703                1.000000  0.158919
# BLK                           0.356624                0.158919  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['STANDING_REACH', 'STANDING_VERTICAL_LEAP', 'BLK', 'DREB', 'HEIGHT_W_SHOES']].corr(), cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_stat = df[['MAX_VERTICAL_LEAP', 'THREE_QUARTER_SPRINT', 'PTS']]
for i in df_stat:
    num = df_stat[i].value_counts()
    bar = sns.barplot(x=num.index, y=num)
    bar.set(xlabel=i, ylabel='Number of Players')
    bar.set_xticklabels(bar.get_xticklabels(), rotation=90, horizontalalignment='right')
    plt.show()

# %%
pd.set_option('display.max_rows', None)
pd.pivot_table(df, index=['POSITION', 'WEIGHT'], values='MODIFIED_LANE_AGILITY_TIME')
# Out:
#                  MODIFIED_LANE_AGILITY_TIME
# POSITION WEIGHT
# C        229.0                     3.310000
#          233.2                     3.030000
#          233.6                     3.000000
#          234.0                     3.160000
#          243.6                     3.120000
#          245.2                     3.000000
#          248.8                     2.990000
#          252.2                     3.480000
#          254.4                     3.220000
#          264.6                     2.940000
# C-PF     241.4                     3.070000
# PF       194.8                     3.480000
#          208.4                     3.060000
#          208.6                     2.940000
#          208.8                     3.240000
#          211.6                     3.150000
#          214.4                     3.030000
#          215.0                     2.810000
#          215.4                     3.200000
#          216.0                     3.090000
# ...

# %%
pd.pivot_table(df, index=['SPOT_NBA_TOP_KEY'], values='FG3M')
# Out:
#                       FG3M
# SPOT_NBA_TOP_KEY
# 0.0               0.333333
# 0.2               0.277778
# 0.4               0.318182
# 0.6               0.425000
# 0.8               0.474074
# 1.0               0.463636

# %%
pd.pivot_table(df, index=['SPOT_COLLEGE_TOP_KEY'], values='FG3M')
# Out:
#                           FG3M
# SPOT_COLLEGE_TOP_KEY
# 0.0                   0.400000
# 0.2                   0.375000
# 0.4                   0.400000
# 0.6                   0.392857
# 0.8                   0.435294
# 1.0                   0.483333
